# %% [markdown]
# Assignment 1: Basic Matrix Operations

# %% [markdown]
# 1. Create two 3×3 matrices with random integers in Python.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

A = np.random.randint(0, 7, size=(3, 3))
B = np.random.randint(0, 90, size=(3, 3))

print("Matrix A:\n", A)
print("Matrix B:\n", B)
# Out:
# Matrix A:
#  [[4 4 5]
#  [3 2 2]
#  [6 5 6]]
# Matrix B:
#  [[ 2 34  0]
#  [85 68 59]
#  [69 45 51]]

# %% [markdown]
# 2. Perform addition, subtraction, and multiplication operations on these matrices.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

A = np.random.randint(0, 7, size=(3, 3))
B = np.random.randint(0, 90, size=(3, 3))


matrix_sum = A + B
matrix_diff = A - B
matrix_prod = np.dot(A, B)
print("Addition: \n", matrix_sum)
print("Subtraction: \n", matrix_diff)
print("Multiplication: \n", matrix_prod)
# Out:
# Addition:
#  [[83 89 84]
#  [33 31 77]
#  [74 73 43]]
# Subtraction:
#  [[-71 -81 -82]
#  [-27 -27 -65]
#  [-72 -73 -35]]
# Multiplication:
#  [[655 699 821]
#  [729 751 625]
#  [369 377 239]]

# %% [markdown]
# 3. Compute the determinant, inverse, and rank of one of the matrices.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

A = np.random.randint(0, 7, size=(3, 3))




det_A = np.linalg.det(A)


if np.linalg.det(A) != 0:
    inv_A = np.linalg.inv(A)
else:
    inv_A = "Matrix is singular, cannot compute inverse"

rank_A = np.linalg.matrix_rank(A)
eigenvalues, eigenvectors = np.linalg.eig(A)
char_poly = np.poly(A)
roots = np.roots(char_poly)
print("Determinant of A:", det_A)
print("Inverse of A:\n", inv_A)
print("Rank of A:", rank_A)
# Out:
# Determinant of A: -23.999999999999993
# Inverse of A:
#  [[ 0.33333333 -0.5         0.08333333]
#  [-1.          1.5         0.25      ]
#  [ 0.          0.25       -0.125     ]]
# Rank of A: 3

# %% [markdown]
# Assignment 2: Matrix Plotting and
# Visualization

# %% [markdown]
# 1. Generate and Plot Two Random Vectors:

# %% [markdown]
# a. Create two vectors, each containing 15 random floats of your choice.

# %%
x = np.random.rand(15)
y = np.random.rand(15)
print("x vector: ",x)
print("y vector: ",y)
# Out:
# x vector:  [0.20556559 0.10069669 0.3880519  0.04958332 0.48418977 0.86074551
#  0.31237047 0.03439792 0.86100805 0.39363548 0.9283521  0.97431791
#  0.69054256 0.49701055 0.97410665]
# y vector:  [0.19116081 0.18923439 0.61284163 0.20898241 0.80034165 0.44111494
#  0.95384661 0.0100837  0.38044353 0.39155567 0.5389477  0.71504278
#  0.67439392 0.97137036 0.45258541]

# %% [markdown]
# b. Plot these vectors on the same graph using matplotlib to compare how
# they look.

# %%
x = np.random.rand(15)
y = np.random.rand(15)
plt.scatter(x, y, color='b', label='Random Points')

# %% [markdown]
# c. Label the axes appropriately and give the plot a title.

# %%
x = np.random.rand(15)
y = np.random.rand(15)
plt.scatter(x, y, color='b', label='Random Points')
plt.title('Scatter Plot of Two Random Vectors')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Generate and Visualize a Random Matrix:

# %% [markdown]
# a. Create a 4x4 matrix with random values of your choice.

# %%
matrix = np.random.rand(4, 4)
print(matrix)
# Out:
# [[0.03871194 0.2893865  0.86552926 0.83080672]
#  [0.86226354 0.65443342 0.85033564 0.05365416]
#  [0.10028483 0.29501667 0.27213716 0.96328295]
#  [0.85799374 0.03319866 0.59995269 0.54742792]]

# %% [markdown]
# b. Display the matrix using a heatmap with appropriate color mapping (e.g.,
# seaborn or matplotlib).

# %%
matrix = np.random.rand(4, 4)
sns.heatmap(matrix, annot=True, cmap='coolwarm', linewidths=0.5, linecolor ='black')
plt.title('Heatmap of 4x4 Matrix')
plt.show()

# %% [markdown]
# c. Add labels to the heatmap to indicate row and column numbers.

# %%
matrix = np.random.rand(4, 4)
plt.figure(figsize=(6, 5))
sns.heatmap(matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, linecolor='black',
            xticklabels=[1, 2, 3, 4],
            yticklabels=[1, 2, 3, 4])
plt.title('Heatmap of 4x4 Random Matrix with Labels')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %% [markdown]
# 3. Matrix Operations and Visualization:

# %% [markdown]
# a. Create two 4x4 matrices with random values of your choice.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

A = np.random.randint(0, 7, size=(4, 4))
B = np.random.randint(0, 90, size=(4, 4))

print("Matrix A:\n", A)
print("Matrix B:\n", B)
# Out:
# Matrix A:
#  [[2 1 5 1]
#  [6 5 4 4]
#  [6 4 6 4]
#  [2 6 0 2]]
# Matrix B:
#  [[77 46 27 29]
#  [34 18 80 27]
#  [79 62 86 70]
#  [49 77 24 21]]

# %% [markdown]
# b. Perform the following operations:
# i. Matrix Addition
# ii. Matrix Subtraction
# iii. Matrix Multiplication (ensure matrices are compatible for
# multiplication)

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

A = np.random.randint(0, 7, size=(4, 4))
B = np.random.randint(0, 90, size=(4, 4))


matrix_sum = A + B
matrix_diff = A - B
matrix_prod = np.dot(A, B)
print("i. Matrix Addition: \n", matrix_sum)
print("ii. Matrix Subtraction: \n", matrix_diff)
print("iii. Matrix Multiplication: \n", matrix_prod)
# Out:
# i. Matrix Addition:
#  [[88 48 45 50]
#  [53 66 15 64]
#  [43 59 57  9]
#  [83 61 39  4]]
# ii. Matrix Subtraction:
#  [[-76 -42 -37 -42]
#  [-51 -64  -3 -64]
#  [-37 -57 -53  -7]
#  [-81 -55 -39   0]]
# iii. Matrix Multiplication:
#  [[1136  929  649  508]
#  [ 374  458  380  158]
#  [ 460  374  281  220]
#  [ 402  356  146  242]]

# %% [markdown]
# c. For each of these operations, visualize the result using bar plots. Each bar
# should represent one element of the matrix.

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
A = np.random.randint(0, 10, size=(4, 4))
B = np.random.randint(0, 10, size=(4, 4))

print("Matrix A:\n", A)
print("Matrix B:\n", B)
matrix_sum = A + B
matrix_diff = A - B
matrix_prod = np.dot(A, B)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].bar(range(1, 17), matrix_sum.flatten(), color='b')
axes[0].set_title('Matrix Addition')
axes[0].set_xlabel('Element Index')
axes[0].set_ylabel('Value')
axes[1].bar(range(1, 17), matrix_diff.flatten(), color='g')
axes[1].set_title('Matrix Subtraction')
axes[1].set_xlabel('Element Index')
axes[1].set_ylabel('Value')
axes[2].bar(range(1, 17), matrix_prod.flatten(), color='r')
axes[2].set_title('Matrix Multiplication')
axes[2].set_xlabel('Element Index')
axes[2].set_ylabel('Value')

plt.tight_layout()
plt.show()
# Out:
# Matrix A:
#  [[9 9 1 1]
#  [7 7 5 4]
#  [2 1 3 3]
#  [1 5 9 8]]
# Matrix B:
#  [[4 1 5 6]
#  [1 5 2 5]
#  [0 3 4 2]
#  [6 7 7 0]]
